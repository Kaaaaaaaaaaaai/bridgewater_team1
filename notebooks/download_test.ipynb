# %%
# Ensure project root is on sys.path (works in Jupyter)
import sys; sys.path.append('../src')
from data.PriceHistory import PriceHistory
import matplotlib.pyplot as plt

# Example usage (uncomment to run)
ph = PriceHistory()
ph.symbol = "XLK"
df = ph.get_price_history()
df['Close'].plot(); plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                  Close        High         Low        Open     Volume
# Date
# 2025-07-23  213.907227  214.906093  212.169209  214.756269   46989300
# 2025-07-24  213.517670  215.445490  213.287935  213.657510   46022600
# 2025-07-25  213.637543  214.996002  213.158076  214.456605   40268800
# 2025-07-28  213.807358  214.606454  212.818475  213.787376   37858000
# 2025-07-29  211.030502  214.566483  210.581016  213.937192   51411700
# 2025-07-30  208.813019  212.149229  207.484525  211.659779   45512500
# 2025-07-31  207.334702  209.602117  206.925163  208.253657   80698400
# 2025-08-01  202.150589  213.337890  201.271582  210.630955  104434500
# 2025-08-04  203.119492  207.644355  201.451371  204.278165   75109300
# 2025-08-05  202.689957  205.107211  201.930824  203.169408   44155100
# 2025-08-06  213.008255  215.135845  205.356935  205.396898  108483100
# 2025-08-07  219.780563  220.599641  216.334477  218.631873   90224800
# ...
